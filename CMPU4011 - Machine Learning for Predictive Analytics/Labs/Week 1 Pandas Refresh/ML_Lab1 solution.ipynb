# %%
import pandas as pd
loans = pd.read_csv('./data/loans.csv', header = None)
loans
# Out:
#     0             1   2     3        4
# 0   1    industrial  34  2.96   repaid
# 1   2  professional  41  4.64  default
# 2   3  professional  36  3.22  default
# 3   4  professional  41  3.11  default
# 4   5    industrial  48  3.80  default
# 5   6    industrial  61  2.52   repaid
# 6   7  professional  37  1.50   repaid
# 7   8  professional  40  1.93   repaid
# 8   9    industrial  33  5.25  default
# 9  10    industrial  32  4.15  default

# %%
loans.columns = ['id', 'occupation', 'age', 'loan-to-salary', 'outcome']
loans
# Out:
#    id    occupation  age  loan-to-salary  outcome
# 0   1    industrial   34            2.96   repaid
# 1   2  professional   41            4.64  default
# 2   3  professional   36            3.22  default
# 3   4  professional   41            3.11  default
# 4   5    industrial   48            3.80  default
# 5   6    industrial   61            2.52   repaid
# 6   7  professional   37            1.50   repaid
# 7   8  professional   40            1.93   repaid
# 8   9    industrial   33            5.25  default
# 9  10    industrial   32            4.15  default

# %%
loans['age']
# Out:
# 0    34
# 1    41
# 2    36
# 3    41
# 4    48
# 5    61
# 6    37
# 7    40
# 8    33
# 9    32
# Name: age, dtype: int64

# %%
loans.age
# Out:
# 0    34
# 1    41
# 2    36
# 3    41
# 4    48
# 5    61
# 6    37
# 7    40
# 8    33
# 9    32
# Name: age, dtype: int64

# %%
loans.dtypes
# Out:
# id                  int64
# occupation         object
# age                 int64
# loan-to-salary    float64
# outcome            object
# dtype: object

# %%
loans.head()
# Out:
#    id    occupation  age  loan-to-salary  outcome
# 0   1    industrial   34            2.96   repaid
# 1   2  professional   41            4.64  default
# 2   3  professional   36            3.22  default
# 3   4  professional   41            3.11  default
# 4   5    industrial   48            3.80  default

# %%
loans[1:4]
# Out:
#    id    occupation  age  loan-to-salary  outcome
# 1   2  professional   41            4.64  default
# 2   3  professional   36            3.22  default
# 3   4  professional   41            3.11  default

# %%
reviews = pd.read_csv('./data/winemag-data-130k-v2.csv')
reviews
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
reviews.country
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
reviews['country']
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
reviews['country'][0]
# Out:
# 'Italy'

# %%
reviews.iloc[0]
# Out:
# Unnamed: 0                                                               0
# country                                                              Italy
# description              Aromas include tropical fruit, broom, brimston...
# designation                                                   Vulkà Bianco
# points                                                                  87
# price                                                                  NaN
# province                                                 Sicily & Sardinia
# region_1                                                              Etna
# region_2                                                               NaN
# taster_name                                                  Kerin O’Keefe
# taster_twitter_handle                                         @kerinokeefe
# title                                    Nicosia 2013 Vulkà Bianco  (Etna)
# ...

# %%
reviews.iloc[:, 0]
# Out:
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
#            ...
# 129966    129966
# 129967    129967
# 129968    129968
# 129969    129969
# 129970    129970
# Name: Unnamed: 0, Length: 129971, dtype: int64

# %%
reviews.iloc[:3, 1]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
reviews.iloc[1:3, 1]
# Out:
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
reviews.iloc[[0, 1, 2], 1]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
reviews.iloc[-5:]
# Out:
#         Unnamed: 0  country  \
# 129966      129966  Germany
# 129967      129967       US
# 129968      129968   France
# 129969      129969   France
# 129970      129970   France
#
#                                               description  \
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
# ...

# %%
reviews.loc[0, 'country']
# Out:
# 'Italy'

# %%
reviews.loc[:, ['taster_name', 'taster_twitter_handle', 'points']]
# Out:
#                taster_name taster_twitter_handle  points
# 0            Kerin O’Keefe          @kerinokeefe      87
# 1               Roger Voss            @vossroger      87
# 2             Paul Gregutt           @paulgwine       87
# 3       Alexander Peartree                   NaN      87
# 4             Paul Gregutt           @paulgwine       87
# ...                    ...                   ...     ...
# 129966  Anna Lee C. Iijima                   NaN      90
# 129967        Paul Gregutt           @paulgwine       90
# 129968          Roger Voss            @vossroger      90
# 129969          Roger Voss            @vossroger      90
# 129970          Roger Voss            @vossroger      90
#
# [129971 rows x 3 columns]

# %%
reviews.set_index("title")
# Out:
#                                                     Unnamed: 0   country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                            0     Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                1  Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)                2        US
# St. Julian 2013 Reserve Late Harvest Riesling (...           3        US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...           4        US
# ...                                                        ...       ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...      129966   Germany
# Citation 2004 Pinot Noir (Oregon)                       129967        US
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)      129968    France
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)           129969    France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...      129970    France
#
# ...

# %%
reviews
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
reviews.country == 'Italy'
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 129966    False
# 129967    False
# 129968    False
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
reviews.loc[reviews.country == 'Italy']
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0   Italy  Aromas include tropical fruit, broom, brimston...
# 6                6   Italy  Here's a bright, informal red that opens with ...
# 13              13   Italy  This is dominated by oak and oak-driven aromas...
# 22              22   Italy  Delicate aromas recall white flower and citrus...
# 24              24   Italy  Aromas of prune, blackcurrant, toast and oak c...
# ...            ...     ...                                                ...
# 129929      129929   Italy  This luminous sparkler has a sweet, fruit-forw...
# 129943      129943   Italy  A blend of Nero d'Avola and Syrah, this convey...
# 129947      129947   Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# 129961      129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962      129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
# ...

# %%
reviews.loc[(reviews.country == 'Italy') & (reviews.points >= 90)]
# Out:
#         Unnamed: 0 country                                        description  \
# 120            120   Italy  Slightly backward, particularly given the vint...
# 130            130   Italy  At the first it was quite muted and subdued, b...
# 133            133   Italy  Einaudi's wines have been improving lately, an...
# 135            135   Italy  The color is just beginning to show signs of b...
# 140            140   Italy  A big, fat, luscious wine with plenty of toast...
# ...            ...     ...                                                ...
# 129929      129929   Italy  This luminous sparkler has a sweet, fruit-forw...
# 129943      129943   Italy  A blend of Nero d'Avola and Syrah, this convey...
# 129947      129947   Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# 129961      129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962      129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
# ...

# %%
reviews.loc[(reviews.country == 'Italy') | (reviews.points >= 90)]
# Out:
#         Unnamed: 0  country  \
# 0                0    Italy
# 6                6    Italy
# 13              13    Italy
# 22              22    Italy
# 24              24    Italy
# ...            ...      ...
# 129966      129966  Germany
# 129967      129967       US
# 129968      129968   France
# 129969      129969   France
# 129970      129970   France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 6       Here's a bright, informal red that opens with ...
# 13      This is dominated by oak and oak-driven aromas...
# 22      Delicate aromas recall white flower and citrus...
# 24      Aromas of prune, blackcurrant, toast and oak c...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
reviews.loc[reviews.country.isin(['Italy', 'France'])]
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0   Italy  Aromas include tropical fruit, broom, brimston...
# 6                6   Italy  Here's a bright, informal red that opens with ...
# 7                7  France  This dry and restrained wine offers spice in p...
# 9                9  France  This has great depth of flavor with its fresh ...
# 11              11  France  This is a dry wine, very spicy, with a tight, ...
# ...            ...     ...                                                ...
# 129964      129964  France  Initially quite muted, this wine slowly develo...
# 129965      129965  France  While it's rich, this beautiful dry wine also ...
# 129968      129968  France  Well-drained gravel soil gives this wine its c...
# 129969      129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970      129970  France  Big, rich and off-dry, this is powered by inte...
#
# ...

# %%
reviews.loc[reviews.price.notnull()]
# Out:
#         Unnamed: 0   country  \
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# 5                5     Spain
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# 5       Blackberry and raspberry aromas show a typical...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
reviews['critic'] = 'everyone'
reviews['critic']
# Out:
# 0         everyone
# 1         everyone
# 2         everyone
# 3         everyone
# 4         everyone
#             ...
# 129966    everyone
# 129967    everyone
# 129968    everyone
# 129969    everyone
# 129970    everyone
# Name: critic, Length: 129971, dtype: object

# %%
reviews['index_backwards'] = range(len(reviews), 0, -1)
reviews['index_backwards']
# Out:
# 0         129971
# 1         129970
# 2         129969
# 3         129968
# 4         129967
#            ...
# 129966         5
# 129967         4
# 129968         3
# 129969         2
# 129970         1
# Name: index_backwards, Length: 129971, dtype: int64

# %% [markdown]
# Lab Questions

# %%
#5.1.	Identify the list of top wines (wines with score at least 99)

reviews[reviews.points > 99]
# Out:
#         Unnamed: 0    country  \
# 345            345  Australia
# 7335          7335      Italy
# 36528        36528     France
# 39286        39286      Italy
# 42197        42197   Portugal
# 45781        45781      Italy
# 45798        45798         US
# 58352        58352     France
# 89728        89728     France
# 89729        89729     France
# 111753      111753     France
# 111754      111754      Italy
# 111755      111755     France
# 111756      111756     France
# 113929      113929         US
# 114972      114972   Portugal
# 118058      118058         US
# 122935      122935     France
# 123545      123545         US
#
#                                               description  \
# 345     This wine contains some material over 100 year...
# 7335    Thick as molasses and dark as caramelized brow...
# 36528   This is a fabulous wine from the greatest Cham...
# 39286   A perfect wine from a classic vintage, the 200...
# ...

# %%
#5.2.	Identify the price of the most expensive wine on the list of of top wines
reviews[reviews.points > 99].price.max()
# Out:
# 1500.0

# %%
#5.3.	Print the details (rows of data) for the most expensive top wine(s)

reviews.price.max()
top_wines = reviews[reviews.points > 99]
df1 = top_wines[top_wines.price == top_wines.price.max()]
df1
# Out:
#         Unnamed: 0 country                                        description  \
# 111753      111753  France  Almost black in color, this stunning wine is g...
# 111755      111755  France  This is the finest Cheval Blanc for many years...
#
#        designation  points   price  province       region_1 region_2  \
# 111753         NaN     100  1500.0  Bordeaux       Pauillac      NaN
# 111755         NaN     100  1500.0  Bordeaux  Saint-Émilion      NaN
#
#        taster_name taster_twitter_handle  \
# 111753  Roger Voss            @vossroger
# 111755  Roger Voss            @vossroger
#
#                                            title                   variety  \
# 111753  Château Lafite Rothschild 2010  Pauillac  Bordeaux-style Red Blend
# 111755  Château Cheval Blanc 2010  Saint-Émilion  Bordeaux-style Red Blend
#
#                            winery    critic  index_backwards
# 111753  Château Lafite Rothschild  everyone            18218
# ...

# %%
#5.4.	Filter the wines that contain “cherry” in the description.

reviews[reviews.description.str.contains('cherry')]
# Out:
#         Unnamed: 0    country  \
# 12              12         US
# 17              17  Argentina
# 19              19         US
# 24              24      Italy
# 27              27      Italy
# ...            ...        ...
# 129960      129960   Portugal
# 129961      129961      Italy
# 129962      129962      Italy
# 129963      129963     Israel
# 129967      129967         US
#
#                                               description  \
# 12      Slightly reduced, this wine offers a chalky, t...
# 17      Raw black-cherry aromas are direct and simple ...
# 19      Red fruit aromas pervade on the nose, with cig...
# 24      Aromas of prune, blackcurrant, toast and oak c...
# 27      Aromas recall ripe dark berry, toast and a whi...
# ...                                                   ...
# 129960  Fresh and fruity, this is full of red cherry f...
# 129961  Intense aromas of wild cherry, baking spice, t...
# 129962  Blackberry, cassis, grilled herb and toasted a...
# ...
